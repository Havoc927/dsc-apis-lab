# %% [markdown]
# # APIs - Cumulative Lab
#
#
# ## Introduction
#
# We've seen how the Yelp API works and how to create basic visualizations using Folium. It's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API.
#
# ## Objectives
#
# You will be able to:
#
# * Practice using functions to organize your code
# * Use pagination to retrieve all results from an API query
# * Practice parsing data returned from an API query
# * Practice interpreting visualizations of a dataset
# * Create maps using Folium

# %% [markdown]
# ## Your Task: Query Yelp for All Businesses in a Category and Analyze the Results
#
# ![restaurant counter with pizza](images/restaurant_counter.jpg)
#
# Photo by <a href="https://unsplash.com/@jordanmadrid?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Jordan Madrid</a> on <a href="/s/photos/pizza-restaurant?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Overview
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. In this lab, you will write a query of businesses on Yelp, then use *pagination* to retrieve all possible results for that query. Then you will create a summary of your findings, including a Folium map of the geographic locations of those businesses.
#
# ### Technical Details
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the **API limits**. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a **maximum of 50 results per request** and defaults to 20. Furthermore, any search will be limited to a **total of 1000 results**. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# Also, be mindful of the **API** ***rate*** **limits**. You can only make **5000 requests per day** and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use `time.sleep(n)` to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a list of dictionaries (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ### Requirements
#
# #### 1. Make the Initial Request
#
# Start by filling in your API key to make the initial request to the business search API. Investigate the structure of the response you get back and start figuring out how you will extract the relevant information.
#
# #### 2. Add Pagination
#
# Using loops and functions, collect the maximum number of results for your query from the API.
#
# #### 3. Perform Exploratory Analysis
#
# Interpret visualizations related to the price range, average rating, and number of reviews for all query results.
#
# #### 4. Create a Folium Map
#
# Using latitude and longitude data, plot the query results on an interactive map.

# %% [markdown]
# ## 1. Make the Initial Request
#
# ### Querying
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you but make the request below.
#
# Use the `requests` library ([documentation here](https://requests.readthedocs.io/en/master/user/quickstart/#make-a-request)).
#
# You'll also need an API key from Yelp. If you haven't done this already, go to the Yelp [Manage App page](https://www.yelp.com/developers/v3/manage_app) and create a new app (after making an account if you haven't already).

# %%
# Replace None with appropriate code

# Import the requests library
import requests

# Get this from the "Manage App" page. Make sure you set them
# back to None before pushing this to GitHub, since otherwise
# your credentials will be compromised
api_key = "NONE"

# These can be whatever you want! But the solution uses "pizza"
# and "New York NY" if you want to compare your work directly
term = "pizza"
location = "New York NY"

# Set up params for request
url = "https://api.yelp.com/v3/businesses/search"
headers = {
    "Authorization": "Bearer {}".format(api_key)
}
url_params = {
    "term": term.replace(" ", "+"),
    "location": location.replace(" ", "+")
}

# Make the request using requests.get, passing in
# url, headers=headers, and params=url_params
response = requests.get(url, headers=headers, params=url_params)

# Confirm we got a 200 response
response
# Out:
# <Response [200]>

# %%
# Run this cell without changes

# Get the response body in JSON format
response_json = response.json()
# View the keys
response_json.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# ### Extracting Data
#
# Now, retrieve the value associated with the `'businesses'` key, and inspect its contents.

# %%
# Replace None with appropriate code

# Retrieve the value from response_json
businesses = response_json["businesses"]

# View the first 2 records
businesses[:2]
# Out:
# [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AaCoCIY53sQkaqrquNKRJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=1R25AVXTD2sQgNNN6z0PFg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1R25AVXTD2sQgNNN6z0PFg',
#   'review_count': 4565,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 1961.8771417367063},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HB5-BoJaVwOP5wLMG57TlA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=1R25AVXTD2sQgNNN6z0PFg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1R25AVXTD2sQgNNN6z0PFg',
#   'review_count': 2546,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 308.56984360837544}]

# %% [markdown]
# ### Preparing Data
#
# Write a function `prepare_data` that takes in a list of dictionaries like `businesses` and returns a copy that has been prepared for analysis:
#
# 1. The `coordinates` key-value pair has been converted into two separate key-value pairs, `latitude` and `longitude`
# 2. All other key-value pairs except for `name`, `review_count`, `rating`, and `price` have been dropped
# 3. All dictionaries missing one of the relevant keys or containing null values have been dropped
#
# In other words, the final keys for each dictionary should be `name`, `review_count`, `rating`, `price`, `latitude`, and `longitude`.
#
# Complete the function in the cell below:

# %%
######SOLUTION##########
def prepare_data(data_list):
    """
    This function takes in a list of dictionaries and prepares it
    for analysis
    """
    
    # Make a new list to hold results
    results = []
    
    for business_data in data_list:
    
        # Make a new dictionary to hold prepared data for this business
        prepared_data = {}
        
        # Extract name, review_count, rating, and price key-value pairs
        # from business_data and add to prepared_data
        # If a key is not present in business_data, add it to prepared_data
        # with an associated value of None
        for key in ("name", "review_count", "rating", "price"):
            prepared_data[key] = business_data.get(key, None)
    
        # Parse and add latitude and longitude columns
        coordinates = business_data["coordinates"]
        prepared_data["latitude"] = coordinates["latitude"]
        prepared_data["longitude"] = coordinates["longitude"]
        
        # Add to list if all values are present
        if all(prepared_data.values()):
            results.append(prepared_data)
    
    return results
    
# Test out function
prepared_businesses = prepare_data(businesses)
prepared_businesses[:5]
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 4565,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2546,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 795,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': 'Rubirosa',
#   'review_count': 2793,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6447,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561}]

# %% [markdown]
# Check that your function created the correct keys:

# %%
# Run this cell without changes

assert sorted(list(prepared_businesses[0].keys())) == ['latitude', 'longitude', 'name', 'price', 'rating', 'review_count']

# %% [markdown]
# The following code will differ depending on your query, but we expect there to be 20 businesses in the original list, and potentially fewer in the prepared list (if any of them were missing data):

# %%
# Run this cell without changes
print("Original:", len(businesses))
print("Prepared:", len(prepared_businesses))
# Out:
# Original: 20
# Prepared: 20

# %% [markdown]
# Great! We will reuse this function once we have retrieved the full dataset.

# %% [markdown]
# ## 2. Add Pagination
#
# Now that you are able to extract information from one page of the response, let's figure out how to request as many pages as possible.
#
# ### Determining the Total
#
# Depending on the number of total results for your query, you will either retrieve all of the results, or just the first 1000 (if there are more than 1000 total).
#
# We can find the total number of results using the `"total"` key:

# %%
# Run this cell without changes
response_json["total"]
# Out:
# 12200

# %% [markdown]
# (This is specific to the implementation of the Yelp API. Some APIs will just tell you that there are more pages, or will tell you the number of pages total, rather than the total number of results. If you're not sure, always check the documentation.)
#
# In the cell below, assign the variable `total` to either the value shown above (if it is less than 1000), or 1000.

# %%
# Replace None with appropriate code
total = 1000

# %% [markdown]
# ### Calculating the Offsets
#
# The documentation states in the parameters section:
#
# > **Name**: `limit`, **Type:** int, **Description:** Optional. Number of business results to return. By default, it will return 20. Maximum is 50.
#
# > **Name**: `offset`, **Type:** int, **Description:** Optional. Offset the list of returned business results by this amount.
#
# So, to get the most results with the fewest API calls we want to set a limit of 50 every time. If, say, we wanted to get 210 total results, that would mean:
#
# 1. Offset of `0` (first 50 records)
# 2. Offset of `50` (second 50 records)
# 3. Offset of `100` (third 50 records)
# 4. Offset of `150` (fourth 50 records)
# 5. Offset of `200` (final 10 records)
#
# In the cell below, create a function `get_offsets` that takes in a total and returns a list of offsets for that total. You can assume that there is a limit of 50 every time.
#
# *Hint: you can use `range` ([documentation here](https://docs.python.org/3.3/library/stdtypes.html?highlight=range#range)) to do this in one line of code. Just make the returned result is a list.*

# %%
# Replace None with appropriate code
def get_offsets(total):
    """
    Get a list of offsets needed to get all pages
    of data up until the total
    """
    return list(range(0, total, 50))

# %% [markdown]
# Check that your function works below:

# %%
# Run this cell without changes

assert get_offsets(200) == [0, 50, 100, 150]
assert get_offsets(210) == [0, 50, 100, 150, 200]

# %% [markdown]
# ### Putting It All Together
#
# Recall that the following variable has already been declared for you:

# %%
# Run this cell without changes
url_params
# Out:
# {'term': 'pizza', 'location': 'New+York+NY'}

# %% [markdown]
# We'll go ahead and also specify that the limit should be 50 every time:

# %%
# Run this cell without changes
url_params["limit"] = 50

# %% [markdown]
# In order to modify the offset, you'll need to add it to `url_params` with the key `"offset"` and whatever value is needed.
#
# In the cell below, write code that:
#
# * Creates an empty list for the full prepared dataset
# * Loops over all of the offsets from `get_offsets` and makes an API call each time with the specified offset
# * Calls `prepare_data` to get a cleaned version of the result of each API call
# * Extends the full prepared dataset list with each query's prepared dataset

# %%
# Get the response body in JSON format
response_json = response.json()
# View the keys
response_json["businesses"]

# %%
# Replace None with appropriate code

# Create an empty list for the full prepared dataset
full_dataset = []

for offset in get_offsets(total):
    # Add or update the "offset" key-value pair in url_params
    url_params["offset"] = offset
    
    # Make the query and get the response
    response = requests.get(url, headers=headers, params=url_params)
    
    # Get the response body in JSON format
    response_json = response.json()
    
    # Get the list of businesses from the response_json
    businesses = response_json["businesses"]
    
    # Call the prepare_data function to get a list of processed data
    prepared_businesses = prepare_data(businesses)
    
    # Extend full_dataset with this list (don't append, or you'll get
    # a list of lists instead of a flat list)
    full_dataset.extend(prepared_businesses)

# Check the length of the full dataset. It will be up to `total`,
# potentially less if there were missing values
len(full_dataset)
# Out:
# 771

# %% [markdown]
# This code may take up to a few minutes to run.
#
# If you get an error trying to get the response body in JSON format, try adding `time.sleep(1)` right after the `requests.get` line, so your code will sleep for 1 second between each API call.

# %% [markdown]
# ## 3. Perform Exploratory Analysis
#
# Take the businesses from the previous question and do an initial exploratory analysis. We have provided some plots for you to interpret:

# %%
# Run this cell without changes
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(16, 5))

# Plot distribution of number of reviews
all_review_counts = [x["review_count"] for x in full_dataset]
ax1.hist(all_review_counts)
ax1.set_title("Review Count Distribution")
ax1.set_xlabel("Number of Reviews")
ax1.set_ylabel("Number of Businesses")

# Plot rating distribution
all_ratings = [x["rating"] for x in full_dataset]
rating_counter = Counter(all_ratings)
rating_keys = sorted(rating_counter.keys())
ax2.bar(rating_keys, [rating_counter[key] for key in rating_keys])
ax2.set_title("Rating Distribution")
ax2.set_xlabel("Rating")
ax2.set_ylabel("Number of Businesses")

# Plot price distribution
all_prices = [x["price"].replace("$", r"\$") for x in full_dataset]
price_counter = Counter(all_prices)
price_keys = sorted(price_counter.keys())
ax3.bar(price_keys, [price_counter[key] for key in price_keys])
ax3.set_title("Price Distribution")
ax3.set_xlabel("Price Category")
ax3.set_ylabel("Number of Businesses");

# %% [markdown]
# Describe the distributions displayed above and interpret them in the context of your query. (Your answer may differ from the solution branch depending on your query.)

# %%
# Replace None with appropriate text
"""
Most businesses are moderately priced at one or two dollar signs out of 4.  Most businesses have at least a 4 star rating and have less than 2000 reviews.
"""
# Out:
# '\nMost businesses are moderately priced at one or two dollar signs out of 4.  Most businesses have at least a 4 star rating and have less than 2000 reviews.\n'

# %% [markdown]
# In the cell below, we also plot the rating distributions by price. In this setup, a price of one dollar sign is "lower price" and everything else is "higher price".

# %%
# Run this cell without changes

higher_price = []
lower_price = []
for row in full_dataset:
    if row["price"] == "$":
        lower_price.append(row["rating"])
    else:
        higher_price.append(row["rating"])
        
fig, ax = plt.subplots()

ax.hist([higher_price, lower_price], label=["higher price", "lower price"], density=True)

ax.legend();

# %% [markdown]
# Is a higher price associated with a higher rating? (No need for any additional math/statistics, just interpret what you see in the plot.)

# %%
# Replace None with appropriate text
"""
Yes.  From a 4 star rating onwards, there is more higher priced restaurants than on the lower side of ratings.
"""

# %% [markdown]
# Finally, let's look at ratings vs. review counts:

# %%
# Run this cell without changes
fig, ax = plt.subplots(figsize=(16,5))

ax.scatter(all_review_counts, all_ratings, alpha=0.2)
ax.set_xlabel("Number of Reviews")
ax.set_ylabel("Rating")
# "zoom in" to a subset of review counts
ax.set_xlim(left=0, right=1000);

# %% [markdown]
# Is a higher number of reviews associated with a higher rating?

# %%
# Replace None with appropriate text
"""
No.  Most restaurants have less than 500 reviews and are mostly spread between 3.5-4 star reviews.  Restaurants pass the 500 review mark haven't been given 3 or 5 star ratings (there could be data missing).
"""

# %%
full_dataset
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 4565,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2546,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 796,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': 'Rubirosa',
#   'review_count': 2793,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6447,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561},
#  {'name': 'Lucali',
#   'review_count': 1884,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.681840746711224,
#   'longitude': -74.0003327},
#  {'name': "Joe's Pizza",
#   'review_count': 2897,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73060076,
#   'longitude': -74.00215997},
#  {'name': "Joe's Pizza",
#   'review_count': 1653,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7547,
#   'longitude': -73.98696},
#  {'name': "Grimaldi's Pizzeria",
#   'review_count': 4869,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7026459,
#   'longitude': -73.9932413},
#  {'name': "Scarr's Pizza",
#   'review_count': 628,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71534,
#   'longitude': -73.9914},
#  {'name': "John's of Bleecker Street",
#   'review_count': 2404,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73158,
#   'longitude': -74.00332},
#  {'name': "Joe's Pizza",
#   'review_count': 1013,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73331,
#   'longitude': -73.98763},
#  {'name': "Paulie Gee's",
#   'review_count': 1323,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.729546,
#   'longitude': -73.958568},
#  {'name': 'Piz-zetta',
#   'review_count': 322,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69116658201196,
#   'longitude': -73.99065911521895},
#  {'name': 'Olio e Più',
#   'review_count': 3720,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.733798036104304,
#   'longitude': -73.99977392649927},
#  {'name': "MAMA'S TOO!",
#   'review_count': 579,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.80084,
#   'longitude': -73.96766},
#  {'name': 'Front Street Pizza',
#   'review_count': 429,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70244,
#   'longitude': -73.98943},
#  {'name': "Joe's Pizza",
#   'review_count': 387,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7101297729083,
#   'longitude': -74.0077206864953},
#  {'name': 'Bleecker Street Pizza',
#   'review_count': 2728,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7320627016512,
#   'longitude': -74.0036552270137},
#  {'name': "Joe's Pizza",
#   'review_count': 424,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7168952,
#   'longitude': -73.95892996733771},
#  {'name': 'Sottocasa Pizzeria',
#   'review_count': 690,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.688285,
#   'longitude': -73.989006},
#  {'name': "Lil Frankie's",
#   'review_count': 1382,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.723625,
#   'longitude': -73.988555},
#  {'name': "Roberta's",
#   'review_count': 3193,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70493,
#   'longitude': -73.93399},
#  {'name': "Adrienne's Pizzabar",
#   'review_count': 1803,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7043362,
#   'longitude': -74.0101733},
#  {'name': 'L & B Spumoni Gardens',
#   'review_count': 4410,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.594715,
#   'longitude': -73.981316},
#  {'name': 'Nolita Pizza',
#   'review_count': 166,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7208883,
#   'longitude': -73.9962404},
#  {'name': 'Barano',
#   'review_count': 305,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.710372,
#   'longitude': -73.96794},
#  {'name': 'Di Fara Pizza',
#   'review_count': 3872,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.625093,
#   'longitude': -73.961531},
#  {'name': "Paulie Gee's Slice Shop",
#   'review_count': 295,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72836,
#   'longitude': -73.9572},
#  {'name': "Brooklyn's Homeslice Pizzeria",
#   'review_count': 183,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.680702,
#   'longitude': -73.967455},
#  {'name': "Ignazio's",
#   'review_count': 593,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.703137,
#   'longitude': -73.993608},
#  {'name': "Ace's Pizza",
#   'review_count': 117,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71505,
#   'longitude': -73.958365},
#  {'name': 'Ops',
#   'review_count': 178,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70276,
#   'longitude': -73.9171},
#  {'name': "Dellarocco's Brick Oven Pizza",
#   'review_count': 331,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6950309,
#   'longitude': -73.9961252},
#  {'name': 'La Nonna Krispy Krust Pizza',
#   'review_count': 70,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.717953,
#   'longitude': -73.9637027},
#  {'name': 'Village Square Pizza',
#   'review_count': 247,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72748,
#   'longitude': -73.98268},
#  {'name': 'East Village Pizza',
#   'review_count': 452,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.728199,
#   'longitude': -73.985182},
#  {'name': 'Unregular Pizza',
#   'review_count': 143,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73398,
#   'longitude': -73.98961},
#  {'name': 'Marinara Pizza',
#   'review_count': 312,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7826,
#   'longitude': -73.95351},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 4132,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7321124557704,
#   'longitude': -73.9839056828882},
#  {'name': 'Song E Napule',
#   'review_count': 640,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72813,
#   'longitude': -74.00188},
#  {'name': 'Song E Napule',
#   'review_count': 640,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72813,
#   'longitude': -74.00188},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 603,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6818695,
#   'longitude': -73.976181},
#  {'name': "Luigi's Pizzeria",
#   'review_count': 279,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6897,
#   'longitude': -73.965369},
#  {'name': 'Il Porto',
#   'review_count': 376,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6974427,
#   'longitude': -73.9675197},
#  {'name': "Lombardo's of Bay Ridge",
#   'review_count': 184,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.634741,
#   'longitude': -74.0284259},
#  {'name': 'Norma',
#   'review_count': 563,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743553,
#   'longitude': -73.980026},
#  {'name': 'Stone Bridge Pizza & Salad',
#   'review_count': 310,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.75225,
#   'longitude': -73.98061},
#  {'name': 'Il Mattone',
#   'review_count': 100,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.720799,
#   'longitude': -74.0091255},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 646,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76458,
#   'longitude': -73.98247},
#  {'name': 'Siena Pizza & Cannoli',
#   'review_count': 81,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.708152,
#   'longitude': -74.013864},
#  {'name': 'Champion Pizza',
#   'review_count': 399,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7215270996094,
#   'longitude': -73.9970855712891},
#  {'name': 'Roebling Pizza',
#   'review_count': 134,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7084890714263,
#   'longitude': -73.9610940711639},
#  {'name': "Rosa's Pizza",
#   'review_count': 176,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7139499,
#   'longitude': -73.95563},
#  {'name': 'NY Pizza Suprema',
#   'review_count': 2353,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7502059936523,
#   'longitude': -73.9953231811523},
#  {'name': 'Fornino',
#   'review_count': 288,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.692930215177675,
#   'longitude': -74.00165153160219},
#  {'name': 'Tailfeather',
#   'review_count': 29,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.69415,
#   'longitude': -73.96089},
#  {'name': 'Saraghina Pizzeria',
#   'review_count': 983,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6837407,
#   'longitude': -73.9353473},
#  {'name': 'Ci Siamo',
#   'review_count': 178,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.75240549384363,
#   'longitude': -73.9982864846782},
#  {'name': 'Ribalta Pizza',
#   'review_count': 711,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7334346,
#   'longitude': -73.9916923},
#  {'name': "Patrizia's - Williamsburg",
#   'review_count': 769,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7109154314181,
#   'longitude': -73.9673637711639},
#  {'name': 'Da Andrea',
#   'review_count': 1616,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.736218,
#   'longitude': -73.99597},
#  {'name': 'Adoro Lei',
#   'review_count': 352,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.725612,
#   'longitude': -74.007916},
#  {'name': 'My Pie Pizzeria Romana',
#   'review_count': 870,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7608512,
#   'longitude': -73.9694809},
#  {'name': 'Made In New York Pizza',
#   'review_count': 464,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.783841,
#   'longitude': -73.977569},
#  {'name': 'Pizza Moto',
#   'review_count': 225,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6746224,
#   'longitude': -74.0007999},
#  {'name': "Saluggi's",
#   'review_count': 588,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.720131370119134,
#   'longitude': -74.00362290743904},
#  {'name': 'Montesacro Pinseria Brooklyn',
#   'review_count': 208,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71338,
#   'longitude': -73.95136},
#  {'name': 'Razza Pizza Artigianale',
#   'review_count': 1111,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7177490485075,
#   'longitude': -74.0441924355125},
#  {'name': 'Krispy Pizza ',
#   'review_count': 310,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62236,
#   'longitude': -74.0055},
#  {'name': 'Williamsburg Pizza',
#   'review_count': 265,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71822,
#   'longitude': -73.99123},
#  {'name': "Vinnie's Pizzeria",
#   'review_count': 729,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7189,
#   'longitude': -73.956843},
#  {'name': 'Stage Door Pizzeria',
#   'review_count': 279,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.712121,
#   'longitude': -74.009704},
#  {'name': 'La Villa',
#   'review_count': 572,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6743319055498,
#   'longitude': -73.9816949398812},
#  {'name': 'Leuca',
#   'review_count': 401,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.722121,
#   'longitude': -73.956678},
#  {'name': 'Time Out Market New York',
#   'review_count': 413,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70342863348067,
#   'longitude': -73.99214637055226},
#  {'name': 'Inatteso Pizzabar',
#   'review_count': 342,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7056571,
#   'longitude': -74.0172056},
#  {'name': 'Fascati Pizza',
#   'review_count': 260,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6985,
#   'longitude': -73.99273},
#  {'name': "Louie's Pizza",
#   'review_count': 511,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.74600424769782,
#   'longitude': -73.88356062541311},
#  {'name': 'Marinara Pizza',
#   'review_count': 20,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72981,
#   'longitude': -73.98658},
#  {'name': 'Fornino- Greenpoint',
#   'review_count': 244,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.728949,
#   'longitude': -73.953999},
#  {'name': "Emmett's",
#   'review_count': 580,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727303,
#   'longitude': -74.00243},
#  {'name': "Graziella's",
#   'review_count': 482,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6904563903809,
#   'longitude': -73.9696273803711},
#  {'name': '&pizza - Wall Street',
#   'review_count': 137,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7057647,
#   'longitude': -74.0085474},
#  {'name': '&pizza - Astor Place',
#   'review_count': 208,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72977004973229,
#   'longitude': -73.99273619055748},
#  {'name': 'Lo Duca Pizza',
#   'review_count': 142,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6349400235262,
#   'longitude': -73.9625812061059},
#  {'name': "Luigi's Pizza",
#   'review_count': 433,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.66163,
#   'longitude': -73.99334},
#  {'name': 'Best Pizza',
#   'review_count': 684,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7156,
#   'longitude': -73.95352},
#  {'name': 'SIMÒ PIZZA',
#   'review_count': 227,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7392597584612,
#   'longitude': -74.0088130692187},
#  {'name': 'Brunetti Pizza',
#   'review_count': 344,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73829,
#   'longitude': -74.0054},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 257,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72892,
#   'longitude': -73.98411},
#  {'name': 'Luzzos La Pizza Napoletana',
#   'review_count': 1082,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.721836749997586,
#   'longitude': -73.98329136062472},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 427,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6810107667113,
#   'longitude': -73.9771813899279},
#  {'name': 'Luna Pizza',
#   'review_count': 96,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.713245675315,
#   'longitude': -73.998651104496},
#  {'name': 'Centro Pizza Bar & Italian Kitchen',
#   'review_count': 199,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74494463643489,
#   'longitude': -73.95312334111576},
#  {'name': 'Corner Slice',
#   'review_count': 148,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7623377,
#   'longitude': -73.9967579},
#  {'name': 'Lions & Tigers & Squares Detroit Pizza',
#   'review_count': 523,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74506,
#   'longitude': -73.99834},
#  {'name': 'Table 87 - Brooklyn Heights',
#   'review_count': 335,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.691219329834,
#   'longitude': -73.9973449707031},
#  {'name': 'Barboncino Pizza & Bar',
#   'review_count': 1085,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.67206,
#   'longitude': -73.95717},
#  {'name': 'Sottocasa Pizzeria - Harlem',
#   'review_count': 328,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.8055499,
#   'longitude': -73.94746},
#  {'name': 'Underground Pizza',
#   'review_count': 322,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70499,
#   'longitude': -74.00961},
#  {'name': "Mark's Red Hook Pizza",
#   'review_count': 77,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6788288,
#   'longitude': -74.0113214},
#  {'name': 'IL Brigante',
#   'review_count': 477,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.707492,
#   'longitude': -74.002571},
#  {'name': 'Wheated',
#   'review_count': 367,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6465968960541,
#   'longitude': -73.9704950265688},
#  {'name': 'BRADO NYCThinCrust Pizza',
#   'review_count': 159,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6905570310882,
#   'longitude': -73.99494681265617},
#  {'name': 'Follia',
#   'review_count': 263,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7349243164062,
#   'longitude': -73.9855880737305},
#  {'name': 'Emmy Squared Pizza - East Village ',
#   'review_count': 336,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72598,
#   'longitude': -73.98672},
#  {'name': 'Famous Calabria',
#   'review_count': 96,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.711942,
#   'longitude': -73.999349},
#  {'name': "Luzzo's BK",
#   'review_count': 211,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.690706,
#   'longitude': -73.9952269},
#  {'name': 'Margherita NYC',
#   'review_count': 312,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7189865112305,
#   'longitude': -73.9969329833984},
#  {'name': "Freddie & Pepper's",
#   'review_count': 514,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.779999,
#   'longitude': -73.980301},
#  {'name': "Lazzara's Pizza",
#   'review_count': 326,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.754057,
#   'longitude': -73.989497},
#  {'name': 'Loring Place',
#   'review_count': 510,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73293764919451,
#   'longitude': -73.99758608256435},
#  {'name': 'Don Angie',
#   'review_count': 600,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73778,
#   'longitude': -74.00197},
#  {'name': 'Dough Vale',
#   'review_count': 100,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70933,
#   'longitude': -73.95407},
#  {'name': 'Milkflower',
#   'review_count': 737,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7628961,
#   'longitude': -73.9207081},
#  {'name': 'La Lanterna Di Vittorio',
#   'review_count': 1606,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73069,
#   'longitude': -74.00015},
#  {'name': "Beebe's",
#   'review_count': 161,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754827,
#   'longitude': -73.935918},
#  {'name': 'Sofia Pizza Shoppe',
#   'review_count': 240,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75674,
#   'longitude': -73.96431},
#  {'name': "Sam's",
#   'review_count': 233,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.685920715332,
#   'longitude': -73.9945220947266},
#  {'name': 'Don Antonio',
#   'review_count': 1598,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.762711,
#   'longitude': -73.986708},
#  {'name': "Sal & Carmine's Pizza",
#   'review_count': 388,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7983115,
#   'longitude': -73.9694405},
#  {'name': 'Levante',
#   'review_count': 313,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74764,
#   'longitude': -73.94173},
#  {'name': 'Little Italy Pizza',
#   'review_count': 155,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7081041823001,
#   'longitude': -74.0046897976739},
#  {'name': 'The 3 Luigis',
#   'review_count': 96,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6882597,
#   'longitude': -73.9626018},
#  {'name': 'Marta',
#   'review_count': 959,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7445882,
#   'longitude': -73.9847936},
#  {'name': "Patrizia's Pizza and Pasta",
#   'review_count': 732,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7398415,
#   'longitude': -73.9792862},
#  {'name': 'Goodfellas Pizzeria of LIC',
#   'review_count': 77,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75334,
#   'longitude': -73.93716},
#  {'name': 'Jumbo Pizza Coffee Shop',
#   'review_count': 86,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.8280452239988,
#   'longitude': -73.9489363226845},
#  {'name': 'Circa Brewing',
#   'review_count': 395,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69165,
#   'longitude': -73.98603},
#  {'name': "Alphonso's Pizzeria & Trattoria",
#   'review_count': 144,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7143,
#   'longitude': -73.98172},
#  {'name': 'Piacere',
#   'review_count': 700,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7196979,
#   'longitude': -73.9951175},
#  {'name': 'Speedy Romeo',
#   'review_count': 654,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6875154792236,
#   'longitude': -73.959874469611},
#  {'name': 'Public Display of Affection',
#   'review_count': 63,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.67741,
#   'longitude': -73.98265},
#  {'name': 'Emily',
#   'review_count': 886,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68351,
#   'longitude': -73.96643},
#  {'name': "Angelo's Coal Oven Pizzeria",
#   'review_count': 1061,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76492,
#   'longitude': -73.97794},
#  {'name': 'Oregano',
#   'review_count': 479,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7190165,
#   'longitude': -73.9586248},
#  {'name': 'Tino’s Artisan Pizza',
#   'review_count': 94,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71416668884163,
#   'longitude': -74.03979259017832},
#  {'name': 'B Side Pizza & Wine Bar',
#   'review_count': 1247,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76388,
#   'longitude': -73.98821},
#  {'name': "Arturo's",
#   'review_count': 752,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7273563342024,
#   'longitude': -74.0004944801331},
#  {'name': 'Garlic New York Pizza Bar',
#   'review_count': 480,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74516465585421,
#   'longitude': -73.975869},
#  {'name': 'Ogliastro',
#   'review_count': 209,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.674397,
#   'longitude': -73.963448},
#  {'name': 'BarDough',
#   'review_count': 196,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7603523698496,
#   'longitude': -73.9898819848895},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 285,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.70638449968762,
#   'longitude': -73.92288771165168},
#  {'name': 'Rosemary’s',
#   'review_count': 173,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.73512,
#   'longitude': -73.97965},
#  {'name': 'Emily - West Village',
#   'review_count': 889,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.729375015649076,
#   'longitude': -74.00386306706551},
#  {'name': 'Cuts & Slices',
#   'review_count': 217,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6854737,
#   'longitude': -73.9203186},
#  {'name': 'Leo',
#   'review_count': 73,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7125608,
#   'longitude': -73.9567886},
#  {'name': 'Casa Theodoro',
#   'review_count': 134,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75693,
#   'longitude': -73.906747},
#  {'name': 'Leo',
#   'review_count': 73,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7125608,
#   'longitude': -73.9567886},
#  {'name': 'Casa Theodoro',
#   'review_count': 134,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75693,
#   'longitude': -73.906747},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 1672,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74406421842744,
#   'longitude': -74.00655890429283},
#  {'name': 'Williamsburg Pizza',
#   'review_count': 350,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7078768,
#   'longitude': -73.9507711},
#  {'name': 'Enzo Bruni Pizza Gourmet',
#   'review_count': 91,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.783433,
#   'longitude': -73.947932},
#  {'name': 'POSTO NYCThinCrust Pizza',
#   'review_count': 655,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73483,
#   'longitude': -73.98282},
#  {'name': "Carmine's Pizzeria",
#   'review_count': 507,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.714987,
#   'longitude': -73.94414},
#  {'name': "Roey's",
#   'review_count': 160,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73596,
#   'longitude': -74.00093},
#  {'name': "Mike's Pizza",
#   'review_count': 146,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75214,
#   'longitude': -73.934339},
#  {'name': 'Pizzette',
#   'review_count': 64,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70858,
#   'longitude': -73.94357},
#  {'name': 'Motorino Pizzeria Napoletana',
#   'review_count': 261,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7104799,
#   'longitude': -73.96351},
#  {'name': 'House of Pizza & Calzones',
#   'review_count': 170,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.683944,
#   'longitude': -74.00225},
#  {'name': 'Piccolo Trattoria',
#   'review_count': 113,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7591676767848,
#   'longitude': -73.9525466887989},
#  {'name': 'Sauce & Barrel',
#   'review_count': 541,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.707999,
#   'longitude': -74.0142651},
#  {'name': 'VEZZO NYCThinCrust Pizza',
#   'review_count': 1363,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.744435447210506,
#   'longitude': -73.9814189},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 77,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7204894,
#   'longitude': -73.98927},
#  {'name': 'Frank Pepe Pizzeria Napoletana',
#   'review_count': 723,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.9647045,
#   'longitude': -73.8391204},
#  {'name': "Not Ray's Pizza",
#   'review_count': 246,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.68598633824293,
#   'longitude': -73.9740807999429},
#  {'name': 'Santa Panza',
#   'review_count': 214,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6947,
#   'longitude': -73.93068},
#  {'name': 'Singas Famous Pizza',
#   'review_count': 99,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71087,
#   'longitude': -73.95069},
#  {'name': "Tony's Pizzeria & Restaurant",
#   'review_count': 350,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.699286,
#   'longitude': -73.918724},
#  {'name': 'Anna Maria Pizza',
#   'review_count': 386,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7179537220535,
#   'longitude': -73.9574498958145},
#  {'name': 'Sotto 13',
#   'review_count': 1019,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7372,
#   'longitude': -73.99919},
#  {'name': 'Kesté Pizza & Vino',
#   'review_count': 1532,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7093947,
#   'longitude': -74.0048977},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 324,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7658680230835,
#   'longitude': -73.9576601066113},
#  {'name': 'Pizza Secret',
#   'review_count': 218,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6808,
#   'longitude': -73.97764},
#  {'name': "Vic's",
#   'review_count': 545,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72693,
#   'longitude': -73.99319},
#  {'name': 'Proto’s Pizza',
#   'review_count': 113,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.725353,
#   'longitude': -73.989746},
#  {'name': 'Sotto Le Stelle',
#   'review_count': 338,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743656,
#   'longitude': -73.9201782},
#  {'name': "Scott's Pizza Tours",
#   'review_count': 361,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.750244140625,
#   'longitude': -73.9970245361328},
#  {'name': 'Little Italy Pizza',
#   'review_count': 576,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.756482,
#   'longitude': -73.981484},
#  {'name': 'Trapizzino',
#   'review_count': 277,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72043,
#   'longitude': -73.98894},
#  {'name': 'Da Gennaro',
#   'review_count': 1206,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.71832,
#   'longitude': -73.99794},
#  {'name': 'Pizzatown',
#   'review_count': 87,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.680043,
#   'longitude': -73.977872},
#  {'name': 'Paesano of Mulberry Street',
#   'review_count': 1260,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.718554,
#   'longitude': -73.997447},
#  {'name': 'Sotto Le Stelle',
#   'review_count': 338,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743656,
#   'longitude': -73.9201782},
#  {'name': "Scott's Pizza Tours",
#   'review_count': 361,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.750244140625,
#   'longitude': -73.9970245361328},
#  {'name': 'Little Italy Pizza',
#   'review_count': 576,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.756482,
#   'longitude': -73.981484},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 74,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.706518,
#   'longitude': -74.007505},
#  {'name': 'Pizzatown',
#   'review_count': 87,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.680043,
#   'longitude': -73.977872},
#  {'name': 'Numero 28 Ristorante Pizzeria Bar',
#   'review_count': 565,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73041,
#   'longitude': -73.98595},
#  {'name': 'J & V Pizzeria',
#   'review_count': 265,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6199507795829,
#   'longitude': -73.9896828},
#  {'name': 'Campania Coal Fired Pizza',
#   'review_count': 653,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6136093139648,
#   'longitude': -74.033332824707},
#  {'name': 'Love & Dough',
#   'review_count': 240,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.702950557308085,
#   'longitude': -73.98748593042708},
#  {'name': 'Roma Pizza',
#   'review_count': 372,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.77843,
#   'longitude': -73.94863},
#  {'name': 'Motorino',
#   'review_count': 1110,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73039,
#   'longitude': -73.98381},
#  {'name': 'Slice Pizza',
#   'review_count': 55,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75202,
#   'longitude': -73.97376},
#  {'name': 'Tavola',
#   'review_count': 1180,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.755403,
#   'longitude': -73.994516},
#  {'name': 'La Vera Pizzeria & Restaurant',
#   'review_count': 155,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.75408,
#   'longitude': -73.96889},
#  {'name': 'Two Boots Pizza - West Village',
#   'review_count': 50,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73314309005766,
#   'longitude': -74.0027964258894},
#  {'name': 'Krispy Pizza',
#   'review_count': 244,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.713375,
#   'longitude': -74.035044},
#  {'name': "Cecconi's Dumbo",
#   'review_count': 990,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.7033063330116,
#   'longitude': -73.9916549604523},
#  {'name': "Famous Ben's Pizza",
#   'review_count': 381,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7249388,
#   'longitude': -74.002451},
#  {'name': "Rosa's Pizza",
#   'review_count': 435,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72697,
#   'longitude': -73.89564},
#  {'name': "Screamer's Pizzeria",
#   'review_count': 421,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7235518,
#   'longitude': -73.95065},
#  {'name': 'Champion Pizza',
#   'review_count': 160,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.719742,
#   'longitude': -73.9872791},
#  {'name': 'Brooklyn Pizza Market',
#   'review_count': 113,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68273,
#   'longitude': -73.99305},
#  {'name': 'Champion Pizza',
#   'review_count': 89,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73592407559118,
#   'longitude': -73.99391475241151},
#  {'name': "Roberta's Pizza At Broadway Bites",
#   'review_count': 17,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.750099,
#   'longitude': -73.989983},
#  {'name': 'Village Pizza',
#   'review_count': 152,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73927,
#   'longitude': -74.00321},
#  {'name': 'Nonnas 1977',
#   'review_count': 165,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76851,
#   'longitude': -73.90997},
#  {'name': "Rosella's Pizzeria",
#   'review_count': 261,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.710117,
#   'longitude': -74.005661},
#  {'name': 'Coletta',
#   'review_count': 118,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.74094,
#   'longitude': -73.98139},
#  {'name': "Monte's",
#   'review_count': 170,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6775499,
#   'longitude': -73.98724},
#  {'name': "Armando's Pizza",
#   'review_count': 70,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6835403,
#   'longitude': -73.9111862},
#  {'name': 'Osteria Brooklyn',
#   'review_count': 151,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.693154,
#   'longitude': -73.967177},
#  {'name': 'Peperino NYC Pizza',
#   'review_count': 95,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.77275912931571,
#   'longitude': -73.99077586611165},
#  {'name': 'Oath Pizza - New York',
#   'review_count': 254,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7664835,
#   'longitude': -73.9633564},
#  {'name': 'Panzerotti Bites',
#   'review_count': 157,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.683715,
#   'longitude': -73.99227},
#  {'name': "Fazio's",
#   'review_count': 202,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69442,
#   'longitude': -73.91039},
#  {'name': 'Malaparte',
#   'review_count': 385,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73687,
#   'longitude': -74.00812},
#  {'name': 'Milano Pizzeria',
#   'review_count': 36,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7968348033007,
#   'longitude': -73.93813295643352},
#  {'name': 'Pazza Notte',
#   'review_count': 965,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76348,
#   'longitude': -73.978091},
#  {'name': 'Harlem Pizza Co',
#   'review_count': 217,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8029069,
#   'longitude': -73.9510825},
#  {'name': 'Jentana Pizza Restaurant',
#   'review_count': 70,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6375122070312,
#   'longitude': -73.9994735717773},
#  {'name': "Baker's Pizza",
#   'review_count': 122,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72943352874865,
#   'longitude': -73.98130623021373},
#  {'name': "Sicily's Best Pizzeria",
#   'review_count': 87,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.70517,
#   'longitude': -73.915155},
#  {'name': 'New Park Pizza',
#   'review_count': 979,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6627403949909,
#   'longitude': -73.8403776268684},
#  {'name': "Peppino's Brick Oven Pizza & Restaurant",
#   'review_count': 483,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.668221,
#   'longitude': -73.986936},
#  {'name': 'Quality Italian',
#   'review_count': 1279,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7644044527436,
#   'longitude': -73.9767805051616},
#  {'name': "Dani's House of Pizza",
#   'review_count': 1142,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7090018174257,
#   'longitude': -73.830498211479},
#  {'name': "Saluggi's East",
#   'review_count': 131,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.715948062187,
#   'longitude': -73.9873785183775},
#  {'name': 'Artistic Pizza',
#   'review_count': 97,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73068,
#   'longitude': -74.00042},
#  {'name': 'Bravo Pizza',
#   'review_count': 111,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7484899,
#   'longitude': -73.9928},
#  {'name': 'Lucia Pizza',
#   'review_count': 621,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.76032,
#   'longitude': -73.82813},
#  {'name': "Ray's Pizza",
#   'review_count': 389,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7604321973079,
#   'longitude': -73.9839891042824},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 303,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.750427,
#   'longitude': -73.972129},
#  {'name': "Ovest Pizzoteca by Luzzo's",
#   'review_count': 588,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7507476806641,
#   'longitude': -74.0030212402344},
#  {'name': 'Zero Otto Nove',
#   'review_count': 514,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7407551035259,
#   'longitude': -73.9914887388588},
#  {'name': 'Pasta by Hudson',
#   'review_count': 96,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7427486,
#   'longitude': -73.9969892},
#  {'name': "Paul's On Times Square",
#   'review_count': 334,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75522,
#   'longitude': -73.98539},
#  {'name': 'Fumo',
#   'review_count': 192,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.80284,
#   'longitude': -73.968119},
#  {'name': "Pop's Pizzas",
#   'review_count': 123,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.767086,
#   'longitude': -73.983033},
#  {'name': "Rosario's",
#   'review_count': 185,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77479,
#   'longitude': -73.91186},
#  {'name': 'Carranza Pizza',
#   'review_count': 9,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.669342,
#   'longitude': -73.896667},
#  {'name': "Waldy's Wood Fired Pizza & Penne",
#   'review_count': 859,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7457666039821,
#   'longitude': -73.9906402533629},
#  {'name': "Denino's Greenwich Village",
#   'review_count': 251,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7294,
#   'longitude': -74.00111},
#  {'name': 'Piatto',
#   'review_count': 226,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7435117,
#   'longitude': -73.9590968},
#  {'name': 'Pizza Plus',
#   'review_count': 267,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.66585,
#   'longitude': -73.98211},
#  {'name': 'San Matteo Pizza and Espresso Bar',
#   'review_count': 549,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7804,
#   'longitude': -73.95012},
#  {'name': 'sLICe LIC',
#   'review_count': 444,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74367,
#   'longitude': -73.95345},
#  {'name': "Tony's Di Napoli",
#   'review_count': 801,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.764385574147596,
#   'longitude': -73.96426247506157},
#  {'name': 'Emmy Squared Pizza - Upper East Side',
#   'review_count': 233,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.77564,
#   'longitude': -73.9565},
#  {'name': "Rizzo's Fine Pizza",
#   'review_count': 647,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76335,
#   'longitude': -73.91516},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 566,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7785204,
#   'longitude': -73.9769718},
#  {'name': "John's of Times Square",
#   'review_count': 2312,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.75823,
#   'longitude': -73.98836},
#  {'name': "Rosa's Pizza",
#   'review_count': 301,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.712192,
#   'longitude': -73.899997},
#  {'name': "L'Artusi",
#   'review_count': 2154,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73372,
#   'longitude': -74.00513},
#  {'name': 'Rosario Pizza',
#   'review_count': 21,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.69408,
#   'longitude': -73.918556},
#  {'name': "Angelo's Pizza",
#   'review_count': 635,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7638169909039,
#   'longitude': -73.9827420901337},
#  {'name': 'Spunto',
#   'review_count': 461,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7297584,
#   'longitude': -74.0046303},
#  {'name': 'Krave It Pizza & Sandwich Joint ',
#   'review_count': 57,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.764537,
#   'longitude': -73.916935},
#  {'name': 'La Nostra Pizzeria',
#   'review_count': 95,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.79316,
#   'longitude': -73.94018},
#  {'name': 'Layla Jones',
#   'review_count': 205,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68669,
#   'longitude': -73.9941},
#  {'name': 'Coco Pazzo',
#   'review_count': 141,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72602,
#   'longitude': -74.00847},
#  {'name': 'Naked Dog',
#   'review_count': 263,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7312720665479,
#   'longitude': -73.9593493647979},
#  {'name': 'Boutros',
#   'review_count': 180,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.6901481293837,
#   'longitude': -73.9935445412993},
#  {'name': "Jiannetto's Pizza Truck",
#   'review_count': 35,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.70525,
#   'longitude': -74.00675},
#  {'name': "Joe & John's Pizzeria",
#   'review_count': 170,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7003933525757,
#   'longitude': -73.8993881901177},
#  {'name': '2 Bros Pizza',
#   'review_count': 621,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.72866,
#   'longitude': -73.988487},
#  {'name': 'Eleven B',
#   'review_count': 234,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72745,
#   'longitude': -73.97974},
#  {'name': 'Emporio',
#   'review_count': 850,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.722647,
#   'longitude': -73.995246},
#  {'name': "Frank's Trattoria",
#   'review_count': 167,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.73612,
#   'longitude': -73.979473},
#  {'name': 'Gnocco',
#   'review_count': 552,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72713,
#   'longitude': -73.9802799},
#  {'name': "J's Pizza",
#   'review_count': 142,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7398164,
#   'longitude': -73.9989453},
#  {'name': 'Parm',
#   'review_count': 403,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.714473491420726,
#   'longitude': -74.01609333303082},
#  {'name': "Percy's Pizza",
#   'review_count': 250,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.729076,
#   'longitude': -74.001534},
#  {'name': 'Shelter Pizza',
#   'review_count': 332,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.71967,
#   'longitude': -73.9608499},
#  {'name': 'Obicà Mozzarella Bar Pizza e Cucina',
#   'review_count': 496,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7400486,
#   'longitude': -73.9893018},
#  {'name': 'Il Corallo Trattoria',
#   'review_count': 1105,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7262073,
#   'longitude': -74.0018919},
#  {'name': 'Two Boots Park Slope',
#   'review_count': 162,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6742098,
#   'longitude': -73.9824143},
#  {'name': "Sal's Pizzeria",
#   'review_count': 141,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.68357,
#   'longitude': -73.99504},
#  {'name': 'Keste Wall Street',
#   'review_count': 239,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70907785865903,
#   'longitude': -74.00453980520689},
#  {'name': "Nick's Pizza",
#   'review_count': 572,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.78272735790179,
#   'longitude': -73.9478073},
#  {'name': 'Original Pizza',
#   'review_count': 134,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.63781,
#   'longitude': -73.8963799},
#  {'name': 'Aurora',
#   'review_count': 777,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.715621,
#   'longitude': -73.964757},
#  {'name': 'Pier 76',
#   'review_count': 245,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.640118,
#   'longitude': -74.0759269},
#  {'name': 'Liberty Pizzeria',
#   'review_count': 39,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.693225,
#   'longitude': -73.966018},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 252,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73033,
#   'longitude': -73.98403},
#  {'name': 'Osteria Morini',
#   'review_count': 1263,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7219179851303,
#   'longitude': -73.9976472073402},
#  {'name': 'Capizzi',
#   'review_count': 863,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75744,
#   'longitude': -73.99357},
#  {'name': "Antonio's Pizzeria & Restaurant",
#   'review_count': 257,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6914284,
#   'longitude': -73.9824964},
#  {'name': "Peppino's Brick Oven Pizza & Restaurant",
#   'review_count': 248,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.62984,
#   'longitude': -74.02862},
#  {'name': 'Mama Mia 44 SW',
#   'review_count': 791,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.759761,
#   'longitude': -73.992065},
#  {'name': 'Eataly NYC Flatiron',
#   'review_count': 5967,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74200824886595,
#   'longitude': -73.98993910744127},
#  {'name': 'Lillian Pizzeria',
#   'review_count': 278,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7169776965988,
#   'longitude': -73.8522986602726},
#  {'name': 'Mercado Little Spain',
#   'review_count': 482,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.752435,
#   'longitude': -74.001475},
#  {'name': "Natoli's",
#   'review_count': 319,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.79508,
#   'longitude': -74.06316},
#  {'name': 'La Mia Pizza',
#   'review_count': 25,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73311,
#   'longitude': -73.99011},
#  {'name': 'PizzArte',
#   'review_count': 1221,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7629335072372,
#   'longitude': -73.9776668697596},
#  {'name': 'Eataly NYC Downtown',
#   'review_count': 1152,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.709716,
#   'longitude': -74.011714},
#  {'name': "Rocky's Number II",
#   'review_count': 335,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74442,
#   'longitude': -73.9765},
#  {'name': 'Gran Morsi',
#   'review_count': 448,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.7142052394856,
#   'longitude': -74.0077535494539},
#  {'name': 'Bklyn Pizza',
#   'review_count': 167,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68903,
#   'longitude': -73.92408},
#  {'name': 'La Mia Pizza',
#   'review_count': 25,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73311,
#   'longitude': -73.99011},
#  {'name': 'PizzArte',
#   'review_count': 1221,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7629335072372,
#   'longitude': -73.9776668697596},
#  {'name': "Rocky's Number II",
#   'review_count': 335,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74442,
#   'longitude': -73.9765},
#  {'name': 'Bklyn Pizza',
#   'review_count': 167,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68903,
#   'longitude': -73.92408},
#  {'name': 'San Marino Ristorante',
#   'review_count': 192,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72697,
#   'longitude': -74.00611},
#  {'name': 'Da Nonna Rosa',
#   'review_count': 421,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.67291,
#   'longitude': -73.97697},
#  {'name': 'Pranzo Pizza & Pasta',
#   'review_count': 110,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7036301,
#   'longitude': -74.0101127},
#  {'name': 'Canal Pizza',
#   'review_count': 26,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7153479526233,
#   'longitude': -73.9934167353488},
#  {'name': 'Sacco Pizza',
#   'review_count': 441,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7662658691406,
#   'longitude': -73.9872665405273},
#  {'name': "Louie & Ernie's Pizza",
#   'review_count': 360,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.838288,
#   'longitude': -73.828563},
#  {'name': 'La Vera Pizzeria',
#   'review_count': 66,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74067,
#   'longitude': -73.98218},
#  {'name': 'OddFellows Ice Cream Co.',
#   'review_count': 129,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70325596349647,
#   'longitude': -73.9924016193591},
#  {'name': "Renato's Pizza Masters",
#   'review_count': 450,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7442813,
#   'longitude': -74.0503861},
#  {'name': '314 Pizza Pasta & Cocktail Bar',
#   'review_count': 116,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.8141969,
#   'longitude': -73.9598383},
#  {'name': 'Pizza Barn',
#   'review_count': 484,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.92033366683442,
#   'longitude': -73.86751644723435},
#  {'name': "Tony's Pizzeria of Nassau Ave",
#   'review_count': 62,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.725290886426,
#   'longitude': -73.946226015687},
#  {'name': 'San Marzano Pasta Fresca',
#   'review_count': 1436,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727966,
#   'longitude': -73.988382},
#  {'name': 'Celeste Restaurant',
#   'review_count': 956,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.78666,
#   'longitude': -73.97599},
#  {'name': "Carmine's Italian Restaurant - Times Square",
#   'review_count': 4250,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75749848725768,
#   'longitude': -73.98665333142026},
#  {'name': 'Triangolo Pizza',
#   'review_count': 132,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.73357,
#   'longitude': -73.955116},
#  {'name': "Uncle Tony's Pizza",
#   'review_count': 137,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.82139,
#   'longitude': -73.95066},
#  {'name': 'Mahsil',
#   'review_count': 54,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76342,
#   'longitude': -73.81408},
#  {'name': 'Zia Maria - Chelsea',
#   'review_count': 296,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7454863,
#   'longitude': -73.9993392},
#  {'name': "Elio's",
#   'review_count': 292,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.7767632368091,
#   'longitude': -73.9526632086427},
#  {'name': "Jeannie's",
#   'review_count': 20,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7662427,
#   'longitude': -73.98124349999999},
#  {'name': 'Koronet Pizza',
#   'review_count': 117,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8442869,
#   'longitude': -73.939153},
#  {'name': "Libretto's Pizzeria",
#   'review_count': 216,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74727,
#   'longitude': -73.97721},
#  {'name': 'Little Italy Pizza',
#   'review_count': 101,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74047547591752,
#   'longitude': -73.98757619999999},
#  {'name': "Luke's Lobster Brooklyn Bridge Park",
#   'review_count': 388,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70359,
#   'longitude': -73.99411},
#  {'name': 'Numero 28 Pizzeria',
#   'review_count': 116,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6728509253454,
#   'longitude': -73.97644119066827},
#  {'name': 'Prima Pizza',
#   'review_count': 57,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6937218,
#   'longitude': -73.8527069},
#  {'name': "Nick's Pizza - Forest Hills",
#   'review_count': 939,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71797254115706,
# ...
#   'review_count': 269,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6605221493743,
#   'longitude': -73.9606475830078},
#  {'name': "Victorio's Pizza Plus",
#   'review_count': 98,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.8235512,
#   'longitude': -73.9443512},
#  {'name': 'Scarpetta',
#   'review_count': 2170,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.744509,
#   'longitude': -73.9856},
#  {'name': 'Maspeth Pizza',
#   'review_count': 67,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.72815,
#   'longitude': -73.89206},
#  {'name': 'Hops Hill',
#   'review_count': 68,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.68309,
#   'longitude': -73.96557},
#  {'name': 'Locanda Vini e Olii',
#   'review_count': 334,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.685007,
#   'longitude': -73.962943},
#  {'name': 'Delizia 92',
#   'review_count': 293,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.78152,
#   'longitude': -73.94886},
#  {'name': 'Blaze Pizza',
#   'review_count': 239,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.738388,
#   'longitude': -74.1708115},
#  {'name': 'P&M Classic Pizza & Restaurant',
#   'review_count': 71,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8262239,
#   'longitude': -73.9466905},
#  {'name': 'Coppelia',
#   'review_count': 1470,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7389111700125,
#   'longitude': -73.9999985153443},
#  {'name': 'Osteria Cotta',
#   'review_count': 1019,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.78554,
#   'longitude': -73.97263},
#  {'name': "The Original Sal's Pizza",
#   'review_count': 40,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.700424,
#   'longitude': -73.896354},
#  {'name': 'Da Marino',
#   'review_count': 627,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.76102,
#   'longitude': -73.98526},
#  {'name': 'Cookshop',
#   'review_count': 2258,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.745731881448236,
#   'longitude': -74.00540454907613},
#  {'name': "Mama Maria's Restaurant",
#   'review_count': 136,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68356,
#   'longitude': -73.99517},
#  {'name': 'OMG Pizzeria',
#   'review_count': 158,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.69817,
#   'longitude': -73.92558},
#  {'name': 'Salvatores of Soho',
#   'review_count': 331,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8875232,
#   'longitude': -73.90704},
#  {'name': "Giovanni's Pizzeria & Restaurant",
#   'review_count': 150,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7436186428648,
#   'longitude': -74.0288001558544},
#  {'name': 'Best Pizza On 1st Avenue',
#   'review_count': 147,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7579966,
#   'longitude': -73.9629148},
#  {'name': 'Xtra Cheese Pizza',
#   'review_count': 129,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7651362,
#   'longitude': -73.8182876},
#  {'name': 'Pronto Pizzeria',
#   'review_count': 166,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76346,
#   'longitude': -73.90886},
#  {'name': 'Pronto Pizza',
#   'review_count': 109,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68946,
#   'longitude': -73.99233},
#  {'name': "Junior's Restaurant",
#   'review_count': 5313,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75756463099685,
#   'longitude': -73.98608001118411},
#  {'name': 'Roma Pizza & Restaurant',
#   'review_count': 198,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.674609,
#   'longitude': -73.975037},
#  {'name': "Lee's Tavern",
#   'review_count': 593,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.588756,
#   'longitude': -74.095153},
#  {'name': 'Benvenuti Pizzeria',
#   'review_count': 57,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7097089406072,
#   'longitude': -74.0167829487317},
#  {'name': 'La Pizza & La Pasta at Eataly NYC Downtown',
#   'review_count': 175,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.7102419339859,
#   'longitude': -74.0124460392414},
#  {'name': 'Altro Paradiso',
#   'review_count': 216,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.72549,
#   'longitude': -74.00489},
#  {'name': 'Delizia 92',
#   'review_count': 293,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.78152,
#   'longitude': -73.94886},
#  {'name': 'Blaze Pizza',
#   'review_count': 239,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.738388,
#   'longitude': -74.1708115},
#  {'name': 'P&M Classic Pizza & Restaurant',
#   'review_count': 71,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8262239,
#   'longitude': -73.9466905},
#  {'name': 'Coppelia',
#   'review_count': 1470,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7389111700125,
#   'longitude': -73.9999985153443},
#  {'name': 'Osteria Cotta',
#   'review_count': 1019,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.78554,
#   'longitude': -73.97263},
#  {'name': "The Original Sal's Pizza",
#   'review_count': 40,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.700424,
#   'longitude': -73.896354},
#  {'name': 'Da Marino',
#   'review_count': 627,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.76102,
#   'longitude': -73.98526},
#  {'name': 'Cookshop',
#   'review_count': 2258,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.745731881448236,
#   'longitude': -74.00540454907613},
#  {'name': "Mama Maria's Restaurant",
#   'review_count': 136,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68356,
#   'longitude': -73.99517},
#  {'name': 'OMG Pizzeria',
#   'review_count': 158,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.69817,
#   'longitude': -73.92558},
#  {'name': 'Salvatores of Soho',
#   'review_count': 331,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8875232,
#   'longitude': -73.90704},
#  {'name': "Giovanni's Pizzeria & Restaurant",
#   'review_count': 150,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7436186428648,
#   'longitude': -74.0288001558544},
#  {'name': 'Best Pizza On 1st Avenue',
#   'review_count': 147,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7579966,
#   'longitude': -73.9629148},
#  {'name': 'Xtra Cheese Pizza',
#   'review_count': 129,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7651362,
#   'longitude': -73.8182876},
#  {'name': 'Pronto Pizza',
#   'review_count': 109,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68946,
#   'longitude': -73.99233},
#  {'name': "Junior's Restaurant",
#   'review_count': 5313,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75756463099685,
#   'longitude': -73.98608001118411},
#  {'name': 'Roma Pizza & Restaurant',
#   'review_count': 198,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.674609,
#   'longitude': -73.975037},
#  {'name': "Lee's Tavern",
#   'review_count': 593,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.588756,
#   'longitude': -74.095153},
#  {'name': 'Benvenuti Pizzeria',
#   'review_count': 57,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7097089406072,
#   'longitude': -74.0167829487317},
#  {'name': 'La Pizza & La Pasta at Eataly NYC Downtown',
#   'review_count': 175,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.7102419339859,
#   'longitude': -74.0124460392414},
#  {'name': 'Altro Paradiso',
#   'review_count': 216,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.72549,
#   'longitude': -74.00489},
#  {'name': 'Hearth',
#   'review_count': 777,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.730006,
#   'longitude': -73.983225},
#  {'name': "Katz's Delicatessen",
#   'review_count': 14218,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.722237,
#   'longitude': -73.9875259},
#  {'name': 'Zeppola Bakery',
#   'review_count': 72,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.752672726751186,
#   'longitude': -73.9891},
#  {'name': 'Franny’s Pizzeria & Restaurant',
#   'review_count': 98,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.4038495,
#   'longitude': -73.99164},
#  {'name': "Gino's Restaurant",
#   'review_count': 785,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.63,
#   'longitude': -74.02274},
#  {'name': "Pugsley's Pizza",
#   'review_count': 177,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.85881,
#   'longitude': -73.88475},
#  {'name': 'Pasquale Jones',
#   'review_count': 306,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.7211076542265,
#   'longitude': -73.9968880778813},
#  {'name': 'The Commodore',
#   'review_count': 627,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7138257110445,
#   'longitude': -73.9556050300598},
#  {'name': 'Marlow Bistro',
#   'review_count': 334,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8028109023738,
#   'longitude': -73.9641991912535},
#  {'name': 'Beverley Pizza & Cafe',
#   'review_count': 129,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.64255,
#   'longitude': -73.97832},
#  {'name': 'WILD',
#   'review_count': 492,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.73474,
#   'longitude': -74.00632},
#  {'name': 'Carroll Place',
#   'review_count': 1222,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7287,
#   'longitude': -73.99971},
#  {'name': "Torre's",
#   'review_count': 75,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.61201,
#   'longitude': -73.9836},
#  {'name': 'Ungaro Coal Fired Pizza Cafe',
#   'review_count': 42,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.62624,
#   'longitude': -74.13315},
#  {'name': 'Porto Bello',
#   'review_count': 222,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.770352,
#   'longitude': -73.904303},
#  {'name': "Rosa's Pizza",
#   'review_count': 119,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.767116,
#   'longitude': -73.929744},
#  {'name': 'Da Raffaele',
#   'review_count': 209,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7535386913133,
#   'longitude': -73.9666010811925},
#  {'name': "Famous Original Ray's Pizza",
#   'review_count': 422,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.7632745057344,
#   'longitude': -73.9815969765186},
#  {'name': 'Estancia 460',
#   'review_count': 144,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72379,
#   'longitude': -74.0097399},
#  {'name': 'Family Pizza',
#   'review_count': 66,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.65585,
#   'longitude': -73.96008},
#  {'name': 'Bluebird',
#   'review_count': 168,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.66182,
#   'longitude': -73.96174},
#  {'name': 'La Casa Mia Pizzeria & Restaurante',
#   'review_count': 67,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.5872915,
#   'longitude': -73.9545124},
#  {'name': "Benny Tudino's Pizzeria",
#   'review_count': 725,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74422,
#   'longitude': -74.02915},
#  {'name': 'Gandolfo Pizzeria & Restaurant',
#   'review_count': 60,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.79947,
#   'longitude': -74.008534},
#  {'name': 'La Bella Express',
#   'review_count': 73,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.60204988424311,
#   'longitude': -73.99410419648417},
#  {'name': 'The Brooklyn Firefly',
#   'review_count': 272,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.63468,
#   'longitude': -74.02631},
#  {'name': 'Reichenbach Hall',
#   'review_count': 815,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7508,
#   'longitude': -73.98401},
#  {'name': "Alfie's Pizza",
#   'review_count': 170,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69983,
#   'longitude': -73.83291},
#  {'name': 'Uptown Pizzeria',
#   'review_count': 84,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.75332,
#   'longitude': -74.0253199},
#  {'name': 'V & T Pizzeria & Restaurant',
#   'review_count': 386,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.80334,
#   'longitude': -73.96383},
#  {'name': 'Girello',
#   'review_count': 40,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7195899,
#   'longitude': -74.00703},
#  {'name': 'Buchetta Brick Oven Pizza',
#   'review_count': 220,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7987564,
#   'longitude': -73.9673846},
#  {'name': 'Bella Donna Pizzeria',
#   'review_count': 27,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.71339588236523,
#   'longitude': -73.91075417663387},
#  {'name': 'La Villa Pizzeria',
#   'review_count': 272,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.666538,
#   'longitude': -73.851986},
#  {'name': 'La Strada',
#   'review_count': 70,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.63791,
#   'longitude': -73.99967},
#  {'name': 'Sunny John Pizzeria',
#   'review_count': 40,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6190419,
#   'longitude': -73.9226648},
#  {'name': 'Tony Pepperoni Pizzeria',
#   'review_count': 29,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.613404,
#   'longitude': -73.99635},
#  {'name': 'Urbanspace',
#   'review_count': 682,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754455,
#   'longitude': -73.9760113},
#  {'name': 'Hex & Company',
#   'review_count': 68,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.806595775543094,
#   'longitude': -73.9652416705522},
#  {'name': 'Belli Osteria',
#   'review_count': 285,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6835199838354,
#   'longitude': -73.9669024162476},
#  {'name': 'Da Nico Ristorante',
#   'review_count': 952,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71963,
#   'longitude': -73.99691},
#  {'name': "Sal's Pizzeria",
#   'review_count': 46,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70447,
#   'longitude': -73.91925},
#  {'name': 'Gersi',
#   'review_count': 332,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.683438,
#   'longitude': -73.995711},
#  {'name': "Gino's Pizzeria",
#   'review_count': 80,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.757709,
#   'longitude': -73.915806},
#  {'name': "Mario's Pizzeria",
#   'review_count': 65,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.6893845,
#   'longitude': -73.9704971},
#  {'name': "Marie's 2",
#   'review_count': 81,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.64224,
#   'longitude': -74.07674},
#  {'name': 'Corner Bistro',
#   'review_count': 1614,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.738045638942125,
#   'longitude': -74.0037457},
#  {'name': 'Marlow & Sons',
#   'review_count': 533,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7106126934043,
#   'longitude': -73.9658814005443},
#  {'name': 'La Casa Bella',
#   'review_count': 300,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.590666,
#   'longitude': -73.991456},
#  {'name': 'Carmentas Italian Specialties',
#   'review_count': 136,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70114,
#   'longitude': -73.92677},
#  {'name': "Sabrina's Pizzeria & Restaurant",
#   'review_count': 35,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.708374,
#   'longitude': -73.958327},
#  {'name': 'Parm',
#   'review_count': 843,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72303,
#   'longitude': -73.99567},
#  {'name': 'Luigis Pizza',
#   'review_count': 50,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.64674,
#   'longitude': -74.00883},
#  {'name': 'Trenta Tre Pizzeria',
#   'review_count': 128,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74706,
#   'longitude': -73.98311},
#  {'name': 'Mammas Famous Pizza',
#   'review_count': 63,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.7880242,
#   'longitude': -73.977052},
#  {'name': 'The Ear Inn',
#   'review_count': 418,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.725925,
#   'longitude': -74.009489},
#  {'name': "Mia Zia's",
#   'review_count': 46,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6147717115692,
#   'longitude': -74.0133265033364},
#  {'name': 'Famous Famiglia Pizzeria ',
#   'review_count': 93,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.76569739383,
#   'longitude': -73.9573263022275},
#  {'name': "Mario's Pizza",
#   'review_count': 39,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.62488,
#   'longitude': -73.99929},
#  {'name': 'Astoria Pizza',
#   'review_count': 85,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7662199,
#   'longitude': -73.92055},
#  {'name': "Mekelburg's",
#   'review_count': 109,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71375,
#   'longitude': -73.96704},
#  {'name': 'Vinnie’s Brick Oven Pan Pizza',
#   'review_count': 36,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72345561427916,
#   'longitude': -74.3072699945952},
#  {'name': "Gino's Pizzeria",
#   'review_count': 248,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74776,
#   'longitude': -74.04788}]

# %% [markdown]
# ## 4. Create a Folium Map
#
# Make a map using Folium of the businesses you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.
#
# You can center the map around the latitude and longitude of the first item in `full_dataset`.

# %%
# Replace None with appropriate code

# Import the library
import folium

# Set up center latitude and longitude
center_lat = 40.72308755605564
center_long = -73.99343490196397
##### SOLUTION########
# Initialize map with center lat and long
yelp_map = folium.Map([center_lat, center_long], zoom_start=12)

# Adjust this limit to see more or fewer businesses
limit=100

for business in full_dataset[:limit]:
    # Extract information about business
    lat = business["latitude"]
    long = business["longitude"]
    name = business["name"]
    rating = business["rating"]  
    price = business["price"]
    details = "{}\nPrice: {} Rating:{}".format(name,price,rating)
    
    # Create popup with relevant details
    popup = folium.Popup(details)
    
    # Create marker with relevant lat/long and popup
    marker = folium.Marker(location=[lat, long], popup=popup)
    
    marker.add_to(yelp_map)
    
yelp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you've made multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice interactive map to display the results using Folium! Well done!
